# %% [markdown]
# As noted in QuantEcon, the Plots package uses different backends, one of which is PyPlot. However, I've had trouble accessing some PyPlot functionality using Plots. Furthermore, Julia seems to get confused when you say ```using Plots, PyPlot``` because I think they both use the same names for functions, like ```plot(x,y)```. But, as a work around I can ```import PyPlot``` rather than ```use``` it. The only snitch is that, to access PyPlot functions, you need to type ```PyPlot.``` blah blah; see below.
#
# Another weird thing: when I remove ```using Plots``` and replace it with ```using PyPlot``` I get this error message: ```WARNING: using PyPlot.plot in module Main conflicts with an existing identifier.``` WHAT THE HELL?

# %%
using Plots
using Distributions

# %%
import PyPlot

# %%
x = linspace(0, 10, 200)
y = sin.(x);

# %%
pyplot()
plot(x, y)
# Out:
# <img src="data:image/png;base64,..." />

# %%
PyPlot.plot(x, y, "b-", linewidth=2)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1377e5890>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x13b2aa610>

# %%
fig, ax = PyPlot.subplots()
ax[:plot](x, y, "r-", linewidth=2, label="sine function", alpha=0.6)
ax[:legend](loc="upper center")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x13b997210>)
# PyObject <matplotlib.legend.Legend object at 0x13bb10dd0>

# %%
u = Uniform()
num_rows, num_cols = 2, 3
fig, axes = PyPlot.subplots(num_rows, num_cols, figsize=(16,6))
subplot_num = 0

for i in 1:num_rows
    for j in 1:num_cols
        ax = axes[i, j]
        subplot_num += 1
        # == Generate a normal sample with random mean and std == #
        m, s = rand(u) * 2 - 1, rand(u) + 1
        d = Normal(m, s)
        x = rand(d, 100)
        # == Histogram the sample == #
        ax[:hist](x, alpha=0.6, bins=20)
        ax[:set_title]("histogram $subplot_num")
        ax[:set_xticks]([-4, 0, 4])
        ax[:set_yticks]([])
    end
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x13b83f810>)
